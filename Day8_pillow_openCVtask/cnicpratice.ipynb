# %%
import cv2
import numpy as np 
# Path to the image file
image_path = r'D:\ML1BootCamp\Day8_pillow_openCVtask\cnicsign\real1\09301093.png'

# Read the image using OpenCV
image = cv2.imread(image_path)

# # Check if the image is loaded successfully
# if image is None:
#     print(f"Error: Unable to load the image from the path: {image_path}")
# else:
#     # Display the image
#     cv2.imshow('Modified Image', image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
# Convert the image to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define the lower and upper thresholds for black or dark pixels
lower_black = np.array([0, 0, 0])
upper_black = np.array([180, 255, 100])
# Create a mask for black pixels
black_mask = cv2.inRange(hsv_image, lower_black, upper_black)

# Apply the mask to the original image to extract black pixels
#result_image = cv2.bitwise_and(image, image, mask=black_mask)

image[black_mask !=0] = [0,0,255]
# Display the original image and the result
cv2.imshow('Original Image', image)
# cv2.imshow('Original Image', image)
# cv2.imshow('Result (Black Pixels)', result_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Resize the image using cv2.resize
resized_image = cv2.resize(image, (130, 60))
cv2.imshow('resized_image', resized_image)
# cv2.imshow('Original Image', image)
# cv2.imshow('Result (Black Pixels)', result_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
path = r'D:\ML1BootCamp\Day8_pillow_openCVtask\idcard.jpg'
cnic =cv2.imread(path)
#cv2.rectangle(cnic,(350,220),(480,280),(0,0,255),thickness=2)
plt.imshow(cnic)

# %%
# Define the coordinates for the top-left and bottom-right corners of the ROI
roi_top_left = (350, 220)
roi_bottom_right = (480, 280)

# Draw a rectangle around the defined ROI on the original image
cv2.rectangle(image, roi_top_left, roi_bottom_right, (0, 255, 0), 2)

# Crop the image based on the defined ROI
roi = cnic[roi_top_left[1]:roi_bottom_right[1], roi_top_left[0]:roi_bottom_right[0]]



roi[black_mask !=0] = [0,0,0]
# # Display the original image with the defined ROI
cv2.imshow('Original Image with ROI', cnic)

# # Display the cropped ROI
# cv2.imshow('ROI', roi)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [37], line 13
#       8 # Crop the image based on the defined ROI
#       9 roi = cnic[roi_top_left[1]:roi_bottom_right[1], roi_top_left[0]:roi_bottom_right[0]]
# ---> 13 roi[black_mask !=0] = [0,0,0]
#      14 # # Display the original image with the defined ROI
#      15 cv2.imshow('Original Image with ROI', cnic)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 60 but corresponding boolean dimension is 549

# %%
roi.shape, black_mask.shape
# Out:
# ((60, 130, 3), (549, 1066))

# %%
black_mask.max()
# Out:
# 255

# %%
import numpy as np



hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower = np.array([0, 59, 49])
upper = np.array([0, 100, 100])

mask = cv2.inRange(hsv, lower, upper)

result = cv2.bitwise_and(hsv, hsv, mask=mask)

cv2.imshow("image", result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np 
# Path to the image file
image_path = r'D:\ML1BootCamp\Day8_pillow_openCVtask\cnicsign\real1\09302093.png'

# Read the image using OpenCV
image = cv2.imread(image_path)
resized_image = cv2.resize(image, (130, 60))
#cv2.imshow('resize Image', resized_image)
# Convert the image to HSV
hsv_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2HSV)

# Define the lower and upper thresholds for black or dark pixels
lower_black = np.array([0, 0, 0])
upper_black = np.array([180, 255, 100])
# Create a mask for black pixels
black_mask = cv2.inRange(hsv_image, lower_black, upper_black)

# Apply the mask to the original image to extract black pixels
#result_image = cv2.bitwise_and(image, image, mask=black_mask)

#resized_image[black_mask !=0] = [0,0,255]

# %%
path = r'D:\ML1BootCamp\Day8_pillow_openCVtask\idcard.jpg'
cnic =cv2.imread(path)

# Define the coordinates for the top-left and bottom-right corners of the ROI
roi_top_left = (350, 220)
roi_bottom_right = (480, 280)

# Draw a rectangle around the defined ROI on the original image
#cv2.rectangle(image, roi_top_left, roi_bottom_right, (0, 255, 0), 2)

# Crop the image based on the defined ROI
#roi = cnic[350:480,220,280]
roi = cnic[roi_top_left[1]:roi_bottom_right[1], roi_top_left[0]:roi_bottom_right[0]]



roi[black_mask !=0] = [0,0,0]
# # Display the original image with the defined ROI
cv2.imshow('Original Image with ROI', cnic)

# # Display the cropped ROI
# cv2.imshow('ROI', roi)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
s = r'D:\ML1BootCamp\Day8_pillow_openCVtask\cnicsign\real1\09303093.png'
c = r'D:\ML1BootCamp\Day8_pillow_openCVtask\idcard.jpg'
import matplotlib.pyplot as plt
plt.imshow(signprint(s,c))

# %% [markdown]
# # function to sign

# %%
def signprint(signpath,cnic):

    # Read the image using OpenCV
    image = cv2.imread(signpath)
    resized_image = cv2.resize(image, (130, 60))
    # Convert the image to HSV
    hsv_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2HSV)

    # Define the lower and upper thresholds for black or dark pixels
    lower_black = np.array([0, 0, 0])
    upper_black = np.array([180, 255, 100])
    # Create a mask for black pixels
    black_mask = cv2.inRange(hsv_image, lower_black, upper_black)
    cnic =cv2.imread(cnic)

    # Define the coordinates for the top-left and bottom-right corners of the ROI
    roi_top_left = (350, 220)
    roi_bottom_right = (480, 280)

    # Crop the image based on the defined ROI
    roi = cnic[roi_top_left[1]:roi_bottom_right[1], roi_top_left[0]:roi_bottom_right[0]]
    roi[black_mask !=0] = [0,0,0]


    return cnic

# %% [markdown]
# # storing in file

# %%
import os

cnicpath = r'D:\ML1BootCamp\Day8_pillow_openCVtask\idcard.jpg'
input_folder = r'D:\ML1BootCamp\Day8_pillow_openCVtask\cnicsign\real1'
output_folder = r'D:\ML1BootCamp\Day8_pillow_openCVtask\cnicsign\signedimage'

for filename in os.listdir(input_folder):
    if filename.endswith(".png"):
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)
        result_image = signprint(input_image_path, cnicpath)
        cv2.imwrite(output_image_path, result_image)

print("Processing complete.")
# Out:
# Processing complete.

# %%
black_mask.shape,roi.shape
# Out:
# numpy.ndarray

# %%
black_mask.shape ,image.shape
# Out:
# ((130, 60), (552, 1138, 3))
