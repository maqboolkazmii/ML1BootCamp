# %% [markdown]
# Regex, you never know when they might come in handy. It's one of the "good programmer"'s fundamental yet a few people actually masters them.
#
# Challenge yourself in 30 exercises, just hide the solution in order not to peek ;)

# %%
import re

# %% [markdown]
# 1) Write a Python program to check that a string contains only a certain set of characters (in this case a-z, A-Z and 0-9).

# %%
import re
def machpattern(string):
    pattern = re.compile("[A-Za-z0-9]+")
    return bool(pattern.fullmatch(string))

print(machpattern("ABFabcdef123450")) 
print(machpattern("gj*&o0!}{"))
# Out:
# True
# False

# %% [markdown]
# 2) Write a Python program that matches a string that has an a followed by zero or more b's

# %%
def machpattern(string):
    pattern = '^a(b*)$'
    return bool(re.search(pattern ,string))

print(machpattern("a")) 
print(machpattern("dfb"))
# Out:
# True
# False

# %% [markdown]
# 3) Write a Python program that matches a string that has an a followed by one or more b's

# %%
def machpattern(string):
    pattern = '^a(b+)$'
    return bool(re.search(pattern ,string))

print(machpattern("a")) 
print(machpattern("ab"))
# Out:
# False
# True

# %% [markdown]
# 4) Write a Python program that matches a string that has an a followed by zero or one 'b'

# %%
# Your code here
def machpattern(string):
    pattern = '^a(b*)|(b+)$'
    return bool(re.search(pattern ,string))

print(machpattern("a")) 
print(machpattern("dfb"))
# Out:
# True
# True

# %% [markdown]
# 5) Write a Python program that matches a string that has an a followed by three 'b'

# %%
# Your code here
def machpattern(string):
    pattern = '^ab{3}?'
    return bool(re.search(pattern ,string))

print(machpattern("abbb")) 
print(machpattern("dbb"))
print(machpattern("dbbbbb"))
# Out:
# True
# False
# False

# %% [markdown]
# 6) Write a Python program that matches a string that has an a followed by two to three 'b'.

# %% [markdown]
# {n,m}. This means at least n, and at most m repetitions of the pattern left to it.

# %%
# Your code here
def machpattern(string):
    pattern = 'ab{2,3}'
    return bool(re.search(pattern ,string))

print(machpattern("abbb")) 
print(machpattern("abb"))
print(machpattern("dbbbbb"))
# Out:
# True
# True
# False

# %% [markdown]
# 7) Write a Python program to find sequences of lowercase letters joined with a underscore.

# %%
# Your code here
def machpattern(string):
    pattern = '^[a-z]+_[a-z]+$'
    return bool(re.search(pattern ,string))

print(machpattern("ab_ab")) 
print(machpattern("jk_gd"))
print(machpattern("dertyuibbb"))
# Out:
# True
# True
# False

# %% [markdown]
# 8) Write a Python program to find the sequences of one upper case letter followed by lower case letters.

# %%
# Your code here
def machpattern(string):
    pattern = '^[A-Z]+[a-z]+$'
    return bool(re.search(pattern ,string))

print(machpattern("Abkkk")) 
print(machpattern("jk_gd"))
print(machpattern("Sertyuibbb"))
# Out:
# True
# False
# True

# %% [markdown]
# 9) Write a Python program that matches a string that has an 'a' followed by anything, ending in 'b'.

# %%
# Your code here
def machpattern(string):
    pattern = '^a.*?b$'
    return bool(re.search(pattern ,string))

print(machpattern("abkkkb")) 
print(machpattern("a;b"))
print(machpattern("a b"))
print(machpattern("Sertyuibbb"))
# Out:
# True
# True
# True
# False

# %% [markdown]
# 10) Write a Python program that matches a word at the beginning of a string.

# %%
def machpattern(string):
    pattern = '^\w+'
    return bool(re.search(pattern ,string))

print(machpattern("the school is the good")) 
print(machpattern(" school is the good"))
# Out:
# True
# False

# %% [markdown]
# 11) Write a Python program that matches a word at the end of string, with optional punctuation.

# %%
def machpattern(string):
    pattern = '\w+\S*$'
    return bool(re.search(pattern ,string))

print(machpattern("the school is the good.")) 
print(machpattern(" school is the good "))
# Out:
# True
# False

# %% [markdown]
# 12) Write a Python program that matches a word containing 'z'

# %%
def machpattern(string):
    pattern =  '\w*z.\w*'
    return bool(re.search(pattern ,string))

print(machpattern("the school is the good.")) 
print(machpattern(" school is the good "))
# Out:
# False
# False

# %% [markdown]
# 13) Write a Python program that matches a word containing 'z', not at the start or end of the word.

# %%
# Your code here
import re
def machpattern(string):
    pattern =  '\Bz\B'
    return bool(re.search(pattern ,string))

print(machpattern("zhe zchoolz is the gozod.")) 
print(machpattern(" school is the good "))
# Out:
# True
# False

# %% [markdown]
# 14) Write a Python program to match a string that contains only upper and lowercase letters, numbers, and underscores.

# %%
# Your code here
def matchstring(string):
    pattern = '^[a-zA-Z0-9_]*$'
    return bool(re.search(pattern, string))
print(matchstring("Acjkas92"))
# Out:
# True

# %% [markdown]
# 15) Write a Python program where a string will start with a specific number.

# %%
def matchstring(string):
    pattern = re.compile(r"5")
    return bool(re.search(pattern, string))
print(matchstring("Acjkas92"))
print(matchstring("5cjkas92"))
# Out:
# False
# True

# %% [markdown]
# 16) Write a Python program to remove leading zeros from an IP address

# %%
def remo(string):
    pattern = '\.[0]*'
    return re.sub(pattern,'.', string)
print(remo("216.08.094.196"))
print(remo("2016.008.0094.0196"))
# Out:
# 216.8.94.196
# 2016.8.94.196

# %% [markdown]
# 17) Write a Python program to check for a number at the end of a string.

# %%
# Your code here
def matchstring(string):
    pattern = '[0-9]$'
    return bool(re.search(pattern, string))
print(matchstring("Acjkas955"))
print(matchstring("5cjkas92"))
# Out:
# True
# True

# %% [markdown]
# 18) Write a Python program to search the numbers (0-9) of length between 1 to 3 in a given string.

# %%
# Your code here

def matchstring(string):
    pattern = '[0-9]{1,3}'
    return re.finditer(pattern ,string)
m =matchstring("Exercises number 1, 12, 13, and 345 are important")

for i in m:
 
    print(i.group(0))
# Out:
# 1
# 12
# 13
# 345

# %% [markdown]
# 19) Write a Python program to search some literals strings in a string. Go to the editor
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox', 'dog', 'horse'

# %%
# Your code here
animals = ['fox', 'dog', 'horse']
text = 'The quick brown fox jumps over the lazy dog.'

for animal in animals:
    print(f'Searching for "{animal}" in "{text}" ')
    if re.search(animal,text):
        print("match")
    else:
        print("Not match")
# Out:
# Searching for "fox" in "The quick brown fox jumps over the lazy dog."
# match
# Searching for "dog" in "The quick brown fox jumps over the lazy dog."
# match
# Searching for "horse" in "The quick brown fox jumps over the lazy dog."
# Not match

# %% [markdown]
# 20) Write a Python program to search a literals string in a string and also find the location within the original string where the pattern occurs
#
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox'

# %%
t = 'The quick brown fox jumps over the lazy dog.'
pattern = 'fox'
match = re.search(pattern,t)
if match:
    print(f"{pattern} , {t} found at {match.start()}, {match.end()}")
else:
    print("Not FOUND")
# Out:
# fox , The quick brown fox jumps over the lazy dog. found at 16, 19

# %% [markdown]
# 21) Write a Python program to find the substrings within a string.
#
# Sample text :
#
# 'Python exercises, PHP exercises, C# exercises'
#
# Pattern :
#
# 'exercises'
#
# Note: There are two instances of exercises in the input string.

# %%
# Your code here
text = 'Python exercises, PHP exercises, C# exercises'
pattern = 'exercises'

for match in re.findall(pattern , text):
    print(match)
# Out:
# exercises
# exercises
# exercises

# %% [markdown]
# 22) Write a Python program to find the occurrence and position of the substrings within a string.

# %%
# Your code here
text = 'Python exercises, PHP exercises, C# exercises'
pattern = 'exercises'

for match in re.findall(pattern , text):
    print(f"{match}  position {match.start()}, {match.end()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [47], line 6
#       3 pattern = 'exercises'
#       5 for match in re.findall(pattern , text):
# ----> 6     print(f"{match}  position {match.start()}, {match.end()}")
#
# AttributeError: 'str' object has no attribute 'start'

# %% [markdown]
# 23) Write a Python program to replace whitespaces with an underscore and vice versa.

# %%
# Your code here

# %% [markdown]
# 24) Write a Python program to extract year, month and date from a an url.

# %%
# Your code here

# %% [markdown]
# 25) Write a Python program to convert a date of yyyy-mm-dd format to dd-mm-yyyy format.

# %%
# Your code here

# %% [markdown]
# 26) Write a Python program to match if two words from a list of words starting with letter 'P'.

# %%
# Your code here

# %% [markdown]
# 27) Write a Python program to separate and print the numbers of a given string.

# %%
# Your code here

# %% [markdown]
# 28) Write a Python program to find all words starting with 'a' or 'e' in a given string.

# %%
# Your code here

# %% [markdown]
# 29) Write a Python program to separate and print the numbers and their position of a given string.

# %%
# Your code here

# %% [markdown]
# 30) Write a Python program to abbreviate 'Road' as 'Rd.' in a given string.

# %%
# Your code here
